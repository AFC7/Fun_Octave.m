# %% [markdown]
# <a href="https://colab.research.google.com/github/AFC7/Fun_Octave.m/blob/main/PacrticaFisol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy.core import symbol
from sympy.polys.polyoptions import Symbols
"""
Charla Fisol 2022
Andres Felipe Caro
"""

print("Ejercicio Realizado en el aprendizaje de calculo")

# Se puede importar 3 maneras la funcion 

# import sympy

# import sympy as sp

# from sympy import *  /// recomendado para usar la funtion

from sympy import *

x= symbols('x')
y= symbols('y')

plot(x)
# Out:
# Ejercicio Realizado en el aprendizaje de calculo

# %%
print("Limite de graficas x**2: de 0 a 5 en 'x'")

plot(x**2,(x,0,5))
# Out:
# Limite de graficas x**2: de 0 a 5 en 'x'

# %%
print("Limite de graficas x**2: de 0 a 5 en 'x'")

plot(x**2,(x,0,5))
# Out:
# Limite de graficas x**2: de 0 a 5 en 'x'

# %%
print("Combinacion de graficas")
plot(x**2,cos(x))
# Out:
# Combinacion de graficas

# %%
#Importamos "from sympy.plotting import plot3d" para ver en 3D

from sympy.plotting import plot3d
print("grafica en 3D")

plot3d(x**2+y**2)
# Out:
# grafica en 3D

# %%
from sympy.plotting import plot3d
print("grafica en 3D de silla de montar")

plot3d(x**2-y**2)
# Out:
# grafica en 3D

# %%
f=(2-sqrt(x-2))/(x**2-36)
print(f)
print("limite de f en 6")
limit(f, x, 6)
# Out:
# (2 - sqrt(x - 2))/(x**2 - 36)
# limite de f en 6
# -1/48

# %%
limit(2*x**4-x**2-8*x, x, oo)
# Out:
# oo

# %%
integrate(x)
# Out:
# x**2/2

# %%
plot(sin(x),(x, 0, pi))

# %%
x= symbol('x')
y= funtion('y')
